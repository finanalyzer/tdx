# %%
from openbb import obb

if 'info' in obb.reference:
    obj = obb.reference["info"]["extensions"]["openbb_provider_extension"]
    print([item for item in obj if "tdx" in item])

symbols = "601919,600519,000001,00300"
symbols_a = "601919,600519,000001,600325,600028,600036,430047"
symbol_a = "600325"
symbol_hk = "01658"
provider = "akshare"
start_date="2025-09-08"
end_date="2025-12-31"
# Out:
# Extensions to add: benzinga@1.6.0, bls@1.3.0, cftc@1.3.0, commodity@1.5.1, congress_gov@1.2.2, crypto@1.6.1, currency@1.6.1, derivatives@1.6.1, econdb@1.5.0, economy@1.6.1, equity@1.6.1, etf@1.6.1, federal_reserve@1.6.1, fixedincome@1.6.1, fmp@1.6.0, fred@1.6.0, government_us@1.6.0, imf@2.1.2, imf_utils@2.1.2, index@1.6.1, intrinio@1.6.0, news@1.6.1, oecd@1.6.0, openbb_tdx@0.0.1, polygon@1.5.1, regulators@1.6.1, sec@1.6.0, tiingo@1.6.0, tradingeconomics@1.6.0, us_eia@1.3.0, uscongress@1.2.2, yfinance@1.6.1
#
# Building...
# ['openbb_tdx@0.0.1']
